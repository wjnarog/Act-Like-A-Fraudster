# %%
pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\wjnar\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\wjnar\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Firefox()
driver.get("https://www.landwatch.com/colorado-land-for-sale/undeveloped-land")
#print(driver.page_source)
soup2 = BeautifulSoup(driver.page_source, "html.parser")
driver.quit()
results=soup2.find(class_="_8f63d fc97d")
listings=results.find_all(id="placard-container")

#for listing in listings:
#    listing = listing.find()

# %%
for listing in listings:
    #listingGlanceInfo = listing.find('script')
    listingPrice = listing.find(class_="_6ae86")
    listingAcreage = listing.find(class_="_6a6db")
    listingAddress = listing.find("p")
    listingAgent = listing.find(id="placard-broker").find(class_="daf63").find(class_="_541a6")
    listingCompany = listing.find(id="placard-broker").find(class_="daf63").find(class_="_61da4")
    
    if listingPrice:
        print(listingPrice.text.strip())
    else:
        print("None")
        
    if listingAcreage:
        print(listingAcreage.text.strip())
    else:
        print("None")

    if listingAddress:
        print(listingAddress.text.strip())
    else:
        print("None")

    if listingAgent:
        print(listingAgent.text.strip())
    else:
        print("None")

    if listingCompany:
        print(listingCompany.text.strip())
    else:
        print("None")
    print("")
# Out:
# $18,000
# 5.07 acres
# Fort Garland, CO, 81133, Costilla County
# The Hemingway Land Company
# None
#
# $15,000
# 2.53 acres
# San Luis, CO, 81152, Costilla County
# The Hemingway Land Company
# None
#
# $7,900
# 2.53 acres
# Gold Hawk Ln, Fort Garland, CO, 81152, Costilla County
# Jon Burnett
# Westward Land Holdings
#
# $18,900
# 5 acres
# 22nd St, Alamosa, CO, 81101, Alamosa County
# Jon Burnett
# Westward Land Holdings
#
# $10,300
# 4.33 acres
# San Luis, CO, 81152, Costilla County
# Dr. Quynh Vu, PharmD
# Secure Land Co
#
# $149
# 4.32 acres
# Colorado City, CO, 81152, Costilla County
# Eric Conkling
# Conkling Land Enterprises
#
# $5,299
# 5.87 acres
# San Luis Rd, Blanca, CO, 81123, Costilla County
# Great Land Investments
# GreatLandinvestments.com
#
# $7,937
# 5 acres
# South Central Region, San Luis, CO, 81152, Costilla County
# Nikki Johnson
# Lifetime Land USA
#
# $18,070
# 1.84 acres
# San Luis, CO, 81152, Costilla County
# APXN
# APXN Property
#
# $3,999
# 1.01 acres
# ...

# %%
print(listing.find(id="placard-broker").find(class_="daf63").find(class_="_61da4").text.strip())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(listing.find(id="placard-broker").find(class_="daf63").find(class_="_61da4").text.strip())
#
# NameError: name 'listing' is not defined
